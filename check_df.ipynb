# %%
import pandas as pd

# %%
df = pd.read_excel("job.xlsx")

# %%
df
# Out:
#       Unnamed: 0                                          Job Title  \
# 0              0                                          Marketing
# 1              1                                          Marketing
# 2              2                                          Marketing
# 3              3                        Nhân viên Digital Marketing
# 4              4                 Marketing Director (FMCG Industry)
# ...          ...                                                ...
# 2895        2895  Thực tập sale bộ phận Xuất Nhập Khẩu (Đào Tạo ...
# 2896        2896                  Thực Tập Sinh Truyền Thông Nội Bộ
# 2897        2897           [HCM] Internal Communication Coordinator
# 2898        2898                          Accounting Intern (AR/AP)
# 2899        2899  [HCM] Assistant MD - Trợ Lí Thu Mua (8-Month C...
#
#          Location                    Salary  \
# 0          Hà Nội  Lương: 12 Tr - 18 Tr VND
# 1          Hà Nội   Lương: 5 Tr - 10 Tr VND
# ...

# %%
df.drop_duplicates()
# Out:
#       Unnamed: 0                                          Job Title  \
# 0              0                                          Marketing
# 1              1                                          Marketing
# 2              2                                          Marketing
# 3              3                        Nhân viên Digital Marketing
# 4              4                 Marketing Director (FMCG Industry)
# ...          ...                                                ...
# 2895        2895  Thực tập sale bộ phận Xuất Nhập Khẩu (Đào Tạo ...
# 2896        2896                  Thực Tập Sinh Truyền Thông Nội Bộ
# 2897        2897           [HCM] Internal Communication Coordinator
# 2898        2898                          Accounting Intern (AR/AP)
# 2899        2899  [HCM] Assistant MD - Trợ Lí Thu Mua (8-Month C...
#
#          Location                    Salary  \
# 0          Hà Nội  Lương: 12 Tr - 18 Tr VND
# 1          Hà Nội   Lương: 5 Tr - 10 Tr VND
# ...

# %%
df_filter = df[df["Salary"] == "Lương: Cạnh tranh"].index

# %%
df.drop(df_filter , inplace=True)

# %%
df.shape
# Out:
# (2550, 5)
